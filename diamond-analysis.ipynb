# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 20px; text-align: center;">
#     <h1 style="color: #4A90E2;">Diamond Dataset Analysis </h1>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="text-align: left; font-size: 20px; font-weight: bold; color: black;">
#     Step 1: Load the Diamond Dataset
# </div>

# %%
data = pd.read_csv('/kaggle/input/diamonds/diamonds.csv')
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# <div style="text-align: left; font-size: 20px; font-weight: bold; color: black;">
#     Step 2: Exploratory Data Analysis (EDA) of the Diamond Dataset
# </div>

# %%
# Basic overview

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
data.shape
# Out:
# (53940, 11)

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# 📌 Observations
# ✅ Symmetric: depth, table, x, y, z → (Mean ≈ Median, likely normal distribution)
# ✅ Slight Right Skew: carat → (Mean slightly greater than median, mild skewness)
# ✅ Highly Right-Skewed: price → (Mean much larger than median, indicating expensive diamonds are rare)*

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data['cut'].nunique()
# Out:
# 5

# %%
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data['color'].nunique()
# Out:
# 7

# %%
data['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
data['clarity'].nunique()
# Out:
# 8

# %%
data['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
# check Missing Values

# %%
data.isnull()
# Out:
#        Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0           False  False  False  False    False  False  False  False  False
# 1           False  False  False  False    False  False  False  False  False
# 2           False  False  False  False    False  False  False  False  False
# 3           False  False  False  False    False  False  False  False  False
# 4           False  False  False  False    False  False  False  False  False
# ...           ...    ...    ...    ...      ...    ...    ...    ...    ...
# 53935       False  False  False  False    False  False  False  False  False
# 53936       False  False  False  False    False  False  False  False  False
# 53937       False  False  False  False    False  False  False  False  False
# 53938       False  False  False  False    False  False  False  False  False
# 53939       False  False  False  False    False  False  False  False  False
#
#            y      z
# 0      False  False
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
#Find Duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Check Datatypes & inconsistence

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
data[data['price']<0].count()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data[data['carat']<0].count()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data[data['depth']<0].count()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data[data['table']<0].count()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# <div style="text-align: left; font-size: 20px; font-weight: bold; color: black;">
#     Step 4: Data Visualization
# </div>
#
# <p><strong>In this step, we will create visualizations to better understand the data.</strong></p>

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <div style="text-align: left; font-size: 20px; font-weight: bold; color: black;">
#     Step 2: Checking for Missing Values (Nulls)
# </div>
#
# <p><strong>In this step, we check if the dataset contains any missing values.</strong></p>
#
# <p>We use the following code to check for null values:</p>
#
# <pre>
#     sns.heatmap(data.isnull())
# </pre>
#
# <p>This heatmap indicates whether there are any missing (null) values in the dataset. Each row represents a sample, and each column represents a feature. The cells that are highlighted (in a color) represent missing values, while non-highlighted cells represent valid data points.</p>
#
# <p><strong>Result:</strong></p>
#
# <p>After running the code, we see the following:</p>
#
# <ul>
#     <li>The dataset does not contain any missing (null) values.</li>
#     <li>All the cells in the heatmap are non-highlighted, indicating no missing data.</li>
# </ul>
#
# <p><strong>Conclusion:</strong> There are no missing values in this dataset, and therefore no further steps are needed to handle missing data.</p>

# %%
plt.figure(figsize=(11,9))
data_num = data.select_dtypes(include='number')  
sns.heatmap(data_num.corr(), annot=True, fmt='.1f',linewidths=3)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
data['cut'].value_counts().plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['color'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['clarity'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.scatter(data['price'],data['carat'],color='green',alpha=.5)

# %%
plt.scatter(data['price'],data['x'],color='pink',alpha=.5)

# %%
plt.scatter(data['price'],data['y'],color='blue',alpha=.4)

# %%
plt.scatter(data['price'],data['z'],color='purple',alpha=.5)

# %%
plt.scatter(data['price'],data['table'],color='blue',alpha=.5)

# %%
data.color.groupby(data.cut).value_counts()
# Out:
# cut        color
# Fair       G         314
#            F         312
#            H         303
#            E         224
#            I         175
#            D         163
#            J         119
# Good       E         933
#            F         909
#            G         871
#            H         702
#            D         662
#            I         522
#            J         307
# Ideal      G        4884
#            E        3903
#            F        3826
#            H        3115
#            D        2834
#            I        2093
#            J         896
# Premium    G        2924
#            H        2360
#            E        2337
#            F        2331
#            D        1603
#            I        1428
#            J         808
# Very Good  E        2400
#            G        2299
#            F        2164
#            H        1824
#            D        1513
#            I        1204
#            J         678
# Name: count, dtype: int64

# %%
sns.countplot(x='cut',data=data,hue='color')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
data.clarity.groupby(data.cut).value_counts()
# Out:
# cut        clarity
# Fair       SI2         466
#            SI1         408
#            VS2         261
#            I1          210
#            VS1         170
#            VVS2         69
#            VVS1         17
#            IF            9
# Good       SI1        1560
#            SI2        1081
#            VS2         978
#            VS1         648
#            VVS2        286
#            VVS1        186
#            I1           96
#            IF           71
# Ideal      VS2        5071
#            SI1        4282
#            VS1        3589
#            VVS2       2606
#            SI2        2598
#            VVS1       2047
#            IF         1212
#            I1          146
# Premium    SI1        3575
#            VS2        3357
#            SI2        2949
#            VS1        1989
#            VVS2        870
#            VVS1        616
#            IF          230
#            I1          205
# Very Good  SI1        3240
# ...

# %%
sns.countplot(x='cut',data=data,hue='clarity')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
data.clarity.groupby(data.color).value_counts()
# Out:
# color  clarity
# D      SI1        2083
#        VS2        1697
#        SI2        1370
#        VS1         705
#        VVS2        553
#        VVS1        252
#        IF           73
#        I1           42
# E      VS2        2470
#        SI1        2426
#        SI2        1713
#        VS1        1281
#        VVS2        991
#        VVS1        656
#        IF          158
#        I1          102
# F      VS2        2201
#        SI1        2131
#        SI2        1609
#        VS1        1364
#        VVS2        975
#        VVS1        734
#        IF          385
#        I1          143
# G      VS2        2347
#        VS1        2148
#        SI1        1976
#        SI2        1548
#        VVS2       1443
#        VVS1        999
#        IF          681
#        I1          150
# H      SI1        2275
#        VS2        1643
#        SI2        1563
#        VS1        1169
#        VVS2        608
#        VVS1        585
#        IF          299
# ...

# %%
sns.countplot(x='clarity',data=data,hue='color')
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=data, x='price', y='carat', hue='cut', style='color', s=100, alpha=0.7)
# Out:
# <Axes: xlabel='price', ylabel='carat'>
